# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
croptypes_path = 'eogis/eoml_response_croptypes.gpkg'

# %%
croptypes_gdf = gpd.read_file(croptypes_path)

# %%
croptypes_gdf.head()
# Out:
#                  landuse                                           geometry
# 0  SONSTIGE ACKERFLÄCHEN  POLYGON ((13.96703 48.19236, 13.96709 48.19237...
# 1           WINTERGERSTE  POLYGON ((14.06639 48.19583, 14.06640 48.19575...
# 2             GRÜNBRACHE  POLYGON ((14.00121 48.23825, 14.00118 48.23815...
# 3           WINTERGERSTE  POLYGON ((14.04966 48.18880, 14.05015 48.18898...
# 4             KÖRNERMAIS  POLYGON ((14.00735 48.24179, 14.01297 48.24261...

# %%
croptypes_gdf.plot(column='landuse', figsize=(15,15), cmap='tab20', legend=True);
plt.savefig('landuse.png', dpi=300);
